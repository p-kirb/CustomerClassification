# %% [markdown]
# Starting point for development - start to build decision tree classifier in notebook for rapid development. Will seperate out code more cleanly once workflow has been established.

# %%
import pandas as pd
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
datapath = "../data/"

fullTrainData = pd.read_excel(f"{datapath}existing-customers.xlsx")

print(fullTrainData.columns)
print("Class balance:")
fullTrainData["class"].value_counts()
# Out:
# /home/peter/.local/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['RowID', 'age', 'workclass', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'class'],
#       dtype='object')
# Class balance:
# <=50K    24720
# >50K      7841
# Name: class, dtype: int64

# %%
#removing redundant columns
fullTrainData = fullTrainData.drop(labels=["RowID", "education"], axis=1)
fullTrainData.head()
# Out:
#    age         workclass  education-num      marital-status  \
# 0   39         State-gov             13       Never-married
# 1   50  Self-emp-not-inc             13  Married-civ-spouse
# 2   38           Private              9            Divorced
# 3   53           Private              7  Married-civ-spouse
# 4   28           Private             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country  class
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# ...

# %%
#making labels numerical - 1 for >50K, 0 for <=50K or unknown
fullTrainData["class"] = fullTrainData["class"].map(lambda x: 1 if(x == ">50K") else 0)

# %%
#comverting dataframe to one-hot representation with one column for each possible value of each categorical attribute
fullTrainData = pd.get_dummies(fullTrainData, columns=["workclass", "marital-status", "occupation", "relationship", "race", "sex", "native-country"])
fullTrainData.head()
# Out:
#    age  education-num  capital-gain  capital-loss  hours-per-week  class  \
# 0   39             13          2174             0              40      0
# 1   50             13             0             0              13      0
# 2   38              9             0             0              40      0
# 3   53              7             0             0              40      0
# 4   28             13             0             0              40      0
#
#    workclass_Federal-gov  workclass_Local-gov  workclass_Never-worked  \
# 0                      0                    0                       0
# 1                      0                    0                       0
# 2                      0                    0                       0
# 3                      0                    0                       0
# 4                      0                    0                       0
#
#    workclass_Private  ...  native-country_Portugal  \
# ...

# %%
#splitting features and labels
attributes = fullTrainData.drop(labels=["class"], axis=1)
labels = fullTrainData["class"]

#getting test and train set
trainFeatures, testFeatures, trainLabels, testLabels = train_test_split(attributes, labels, test_size=0.2, random_state=5) #random state is like a seed to allow repeatable results

# %%
#training classifier
treeClassifier = tree.DecisionTreeClassifier(max_depth=8)       #limiting max depth helps prevent overfitting and boosts score
treeClassifier.fit(trainFeatures, trainLabels)

forestClassifier = RandomForestClassifier(max_depth=8, n_estimators=40, max_features=6)
forestClassifier.fit(trainFeatures, trainLabels)
# Out:
# RandomForestClassifier(max_depth=8, max_features=6, n_estimators=40)

# %%
#getting score for classifier based on test dataset
treeScore = treeClassifier.score(testFeatures, testLabels)
forestScore = forestClassifier.score(testFeatures, testLabels)

print(f"tree score: {treeScore}")
print(f"forest score: {forestScore}")
# Out:
# tree score: 0.8550591125441425
# forest score: 0.8392445877475817
